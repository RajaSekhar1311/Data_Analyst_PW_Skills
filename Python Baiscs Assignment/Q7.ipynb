# %% [markdown]
# In Python, **loops** are used to execute a block of code repeatedly until a certain condition is met.
#
# There are two main types of loops: **for** loops and **while** loops.
#
# Let’s explore each type along with their use cases and examples.
#
# 1. **for Loop**
#
# The for loop is used for iterating over a sequence (like a list, tuple, dictionary, set, or string). It is especially useful when you know the number of iterations beforehand.
#
# **Example:**

# %%
# Iterating over a list
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# Use Case: Iterating over elements in a list, performing operations on each element.
#
# 2. **while Loop**
#
# The while loop continues to execute a block of code as long as a specified condition is true. It is useful when the number of iterations is not known beforehand and depends on a condition.
#
# **Example:**

# %%
# Printing numbers from 1 to 5
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Use Case: Repeating an action until a certain condition is met, such as reading user input until a valid response is given.
#
# 3. **Loop Control Statements**
#
# Python provides several control statements to manage the flow of loops:
#
# **break**: Exits the loop prematurely.
#
# **continue**: Skips the rest of the code inside the loop for the current iteration and moves to the next iteration.
#
# **else**: Executes a block of code once when the loop condition is no longer true (only for for and while loops).
#
# **Example:**

# %%
# Using break and continue
for i in range(15):
    if i == 12:
        break  # Exit the loop when i is 12
    if i % 2 == 0:
        continue  # Skip even numbers
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11
